# %% [markdown]
# <a href="https://colab.research.google.com/github/nikhilbyte/GenderNeutrality/blob/main/Sanskrit_Seq2Seq.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !cp -r /content/drive/MyDrive/sans_lm /content/

# %%
# !mkdir ocr-post-correction

# %%
# !cp -r /content/drive/MyDrive/PC_Data /content/ocr-post-correction

# %%
# !pip install simpletransformers
# Out:
# ...
#      |████████████████████████████████| 247 kB 4.2 MB/s
# ...
#      |████████████████████████████████| 9.1 MB 37.2 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 51.9 MB/s
# ...
#      |████████████████████████████████| 43 kB 2.5 MB/s
# ...
#      |████████████████████████████████| 298 kB 62.7 MB/s
# ...
#      |████████████████████████████████| 3.1 MB 71.2 MB/s
# ...
#      |████████████████████████████████| 1.7 MB 64.6 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 79.7 MB/s
# ...
#      |████████████████████████████████| 895 kB 38.2 MB/s
# ...
#      |████████████████████████████████| 61 kB 627 kB/s
# ...
#      |████████████████████████████████| 596 kB 47.9 MB/s
# ...
#      |████████████████████████████████| 180 kB 64.4 MB/s
# ...
#      |████████████████████████████████| 97 kB 8.0 MB/s
# ...
#      |████████████████████████████████| 140 kB 87.5 MB/s
# ...
#      |████████████████████████████████| 63 kB 2.1 MB/s
# ...
#      |████████████████████████████████| 132 kB 90.2 MB/s
# ...
#      |████████████████████████████████| 243 kB 77.3 MB/s
# ...

# %%
train_src = open("/content/ocr-post-correction/PC_Data/ocr-post-correction/train_src.txt", "r")
train_src_list = train_src.readlines()
train_target = open("/content/ocr-post-correction/PC_Data/ocr-post-correction/train_target.txt", "r")
train_target_list = train_target.readlines()
val_src = open("/content/ocr-post-correction/PC_Data/ocr-post-correction/val_src.txt", "r")
val_src_list = val_src.readlines()
val_target = open("/content/ocr-post-correction/PC_Data/ocr-post-correction/val_target.txt", "r")
val_target_list = val_target.readlines()

# %%
import logging

import pandas as pd
from simpletransformers.seq2seq import Seq2SeqModel, Seq2SeqArgs


logging.basicConfig(level=logging.INFO)
transformers_logger = logging.getLogger("transformers")
transformers_logger.setLevel(logging.WARNING)

train_df = pd.DataFrame(zip(train_src_list,train_target_list), columns=["input_text", "target_text"])

eval_df = pd.DataFrame(zip(val_src_list,val_target_list), columns=["input_text", "target_text"])

# Configure the model
model_args = Seq2SeqArgs()
model_args.num_train_epochs = 200
model_args.evaluate_generated_text = True
model_args.evaluate_during_training = False
model_args.evaluate_during_training_verbose = True

# %%
from simpletransformers.seq2seq import Seq2SeqModel


model = Seq2SeqModel(
    "bert",
    "rajratnpranesh/DCS_sanskrit_bert",
    "rajratnpranesh/DCS_sanskrit_bert",
)
# Out:
# Some weights of BertLMHeadModel were not initialized from the model checkpoint at rajratnpranesh/DCS_sanskrit_bert and are newly initialized: ['encoder.layer.7.crossattention.output.LayerNorm.weight', 'encoder.layer.1.crossattention.self.value.bias', 'encoder.layer.5.crossattention.output.LayerNorm.weight', 'encoder.layer.11.crossattention.self.query.weight', 'encoder.layer.11.crossattention.self.key.bias', 'encoder.layer.8.crossattention.self.value.weight', 'encoder.layer.2.crossattention.self.query.bias', 'encoder.layer.7.crossattention.self.value.weight', 'encoder.layer.2.crossattention.output.dense.weight', 'encoder.layer.5.crossattention.output.LayerNorm.bias', 'encoder.layer.3.crossattention.output.LayerNorm.bias', 'encoder.layer.4.crossattention.self.query.weight', 'encoder.layer.4.crossattention.output.dense.bias', 'encoder.layer.8.crossattention.self.query.bias', 'cls.predictions.transform.LayerNorm.weight', 'encoder.layer.5.crossattention.self.value.weight', 'encoder.layer.
# ...

# %%
mkdir seq2seq_model

# %%
import torch

# %%
# !rm -r /content/seq2seq_model/checkpoint-250-epoch-1

# %%
model.train_model(train_df.loc[1:30000], eval_data=eval_df,output_dir="/content/seq2seq_model")
# Out:
# INFO:simpletransformers.seq2seq.seq2seq_utils: Creating features from dataset file at cache_dir/
#   0%|          | 0/30000 [00:00<?, ?it/s]
# INFO:simpletransformers.seq2seq.seq2seq_utils: Saving features into cached file cache_dir/rajratnpranesh_DCS_sanskrit_bert-rajratnpranesh_DCS_sanskrit_bert_cached_12830000
# INFO:simpletransformers.seq2seq.seq2seq_model: Training started
# ...
# Running Epoch 0 of 1:   0%|          | 0/3750 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:490: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# ...

# %%
import sys
print(sys.executable)
print(sys.version)
print(sys.version_info)
# Out:
# /usr/bin/python3
# 3.7.12 (default, Sep 10 2021, 00:21:48)
# [GCC 7.5.0]
# sys.version_info(major=3, minor=7, micro=12, releaselevel='final', serial=0)
